# %% [markdown]
# #  Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# - Practice writing and formatting Markdown and code cells in Jupyter Notebooks.
#
# + Save the notebook and download it for later submission.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. Julia

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. Numpy
# 3. Matplotlib

# %% [markdown]
# |Data Science tools|
# --------------------
# | JupyterLab        |
# | Rstudio           |
# | Jupyter Notebook  |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.
# 1. Addition: n1+n2
# 2. Subtraction: n1-n2
# 3. Multiplication: n1*n2
# 4. Division:n1/n2

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4)+5.
# Out:
# 17.0

# %%
# This will convert 200 minutes to hours hours by diving by 60.


200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author.
# Raghav Malpani
